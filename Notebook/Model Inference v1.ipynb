# %%
import os
import sys
import json
import datetime
import numpy as np
import pandas as pd
import skimage.draw
import matplotlib.pyplot as plt
import keras
# Out:
# Using TensorFlow backend.

# %%
keras.__version__
# Out:
# '2.1.6'

# %%
# Root directory of the project
ROOT_DIR = os.path.abspath("../Mask_RCNN")
# Import Mask RCNN
sys.path.append(ROOT_DIR)
# evaluate the mask rcnn model on the kangaroo dataset
from os import listdir
from xml.etree import ElementTree
from numpy import zeros
from numpy import asarray
from numpy import expand_dims
from numpy import mean
from mrcnn.config import Config
from mrcnn.model import MaskRCNN
from mrcnn.utils import Dataset
from mrcnn.utils import compute_ap
from mrcnn.model import load_image_gt
from mrcnn.model import mold_image
from mrcnn.visualize import display_instances
from mrcnn.utils import extract_bboxes

# Directory to save logs and model checkpoints, if not provided
# through the command line argument --logs
DEFAULT_LOGS_DIR = os.path.join(ROOT_DIR, "logs")

# %%
class CustomDataset(Dataset):

    def load_custom(self, input_dir, subset):
        """Load a subset of the bottle dataset.
        dataset_dir: Root directory of the dataset.
        subset: Subset to load: train or val
        """
        # Add classes. We have only one class to add.
        self.add_class("damage", 1, "scratches")
        self.add_class("damage", 2, "dents")
        #self.add_class("damage", 3, "light_dent")
        #self.add_class("damage", 4, "moderate_dent")
        #self.add_class("damage", 5, "severe_dent")
        
        assert subset in ["train", "val"]
        
        dataset_dir = os.path.join(input_dir, subset)
 
        # Load annotations
        # VGG Image Annotator saves each image in the form:
        # { 'filename': '28503151_5b5b7ec140_b.jpg',
        #   'regions': {
        #       '0': {
        #           'region_attributes': {},
        #           'shape_attributes': {
        #               'all_points_x': [...],
        #               'all_points_y': [...],
        #               'name': 'polygon'}},
        #       ... more regions ...
        #   },
        #   'size': 100202
        # }
        # We mostly care about the x and y coordinates of each region
#         annotations1 = json.load(open(os.path.join(dataset_dir, "via_region_data.json")))
        print(os.path.join(dataset_dir, "via_region_data.json"))
        annotations1 = json.load(open(os.path.join(dataset_dir, "via_region_data.json")))
        # print(annotations1)
        annotations = list(annotations1.values())  # don't need the dict keys
 
        # The VIA tool saves images in the JSON even if they don't have any
        # annotations. Skip unannotated images.
        annotations = [a for a in annotations if a['regions']]

        if subset == 'val':
            for i in listdir(dataset_dir):
                if annotations1.get(i) != None:
                    self.add_img_with_annotations(annotations1[i],dataset_dir)
                else:
                    print(f'No annotation {i}')
        else:
            count = 1
            # Add images
            for a in annotations:
                print(count)
                count+=1
                self.add_img_with_annotations(a,dataset_dir)

    def add_img_with_annotations(self,a, dataset_dir):
            # print(a)
            # Get the x, y coordinaets of points of the polygons that make up
            # the outline of each object instance. There are stores in the
            # shape_attributes (see json format above)
            polygons = [r["shape_attributes"] for r in a["regions"]]
            damages = [r["region_attributes"]["Severity"] for r in a['regions']]
            print("Damages:",damages)
            damage_to_id = {"Light Scratches": 1,
                            "Moderate Scratches": 1,
                            "Light Dent": 2,
                            "Moderate Dent": 2,
                            "Severe Dent": 2 
                        }
            # key = tuple(name_dict)
            num_ids = [damage_to_id[list(damage.keys())[0]] for damage in damages]

            # num_ids = [int(n['Event']) for n in objects]
            # load_mask() needs the image size to convert polygons to masks.
            # Unfortunately, VIA doesn't include it in JSON, so we must read
            # the image. This is only managable since the dataset is tiny.
            print("numids",num_ids)
            image_path = os.path.join(dataset_dir, a['filename'])
            image = skimage.io.imread(image_path) 
            height, width = image.shape[:2]

            self.add_image(
                "damage",  
                image_id=a['filename'],  # file name has a unique image id
                path=image_path,
                width=width, height=height,
                polygons=polygons,
                num_ids=num_ids)
    
    def load_mask(self, image_id):
        """Generate instance masks for an image.
       Returns:
        masks: A bool array of shape [height, width, instance count] with
            one mask per instance.
        class_ids: a 1D array of class IDs of the instance masks.
        """
        # If not a bottle dataset image, delegate to parent class.
        image_info = self.image_info[image_id]
        if image_info["source"] != "damage":
            return super(self.__class__, self).load_mask(image_id)

        # Convert polygons to a bitmap mask of shape
        # [height, width, instance_count]
        info = self.image_info[image_id]
        if info["source"] != "damage":
            return super(self.__class__, self).load_mask(image_id)
        num_ids = info['num_ids']
        mask = np.zeros([info["height"], info["width"], len(info["polygons"])],
                        dtype=np.uint8)
        for i, p in enumerate(info["polygons"]):
            rr, cc = skimage.draw.polygon(p['all_points_y'], p['all_points_x'])
            try:
                mask[rr, cc, i] = 1
            except IndexError:
                print(f"This car is problem ! {image_id}")
                num_ids = np.array(num_ids, dtype=np.int32)
                return mask, num_ids

        # Return mask, and array of class IDs of each instance. Since we have
        # one class ID only, we return an array of 1s
        # Map class names to class IDs.
        num_ids = np.array(num_ids, dtype=np.int32)
        return mask, num_ids

# %%
# define the prediction configuration
class PredictionConfig(Config):
	# define the name of the configuration
	NAME = "damage_cfg"
	# number of classes (background + kangaroo)
	NUM_CLASSES = 1 + 2
	# simplify GPU config
	GPU_COUNT = 1
	IMAGES_PER_GPU = 1

# %%
# calculate the mAP for a model on a given dataset
def evaluate_model(dataset, model, cfg):
	APs = list()
	for image_id in dataset.image_ids:
		# load image, bounding boxes and masks for the image id
		image, image_meta, gt_class_id, gt_bbox, gt_mask = load_image_gt(dataset, cfg, image_id, use_mini_mask=False)
		# convert pixel values (e.g. center)
		scaled_image = mold_image(image, cfg)
		# convert image into one sample
		sample = expand_dims(scaled_image, 0)
		# make prediction
		yhat = model.detect(sample, verbose=0)
		# extract results for first sample
		r = yhat[0]
		# calculate statistics, including AP
		AP, _, _, _ = compute_ap(gt_bbox, gt_class_id, gt_mask, r["rois"], r["class_ids"], r["scores"], r['masks'])
		# store
		APs.append(AP)
	# calculate the mean AP across all images
	mAP = mean(APs)
	return mAP

# %%
# load the train dataset
train_set = CustomDataset()
train_set.load_custom('./dataset_train2', 'train')
train_set.prepare()
print('Train: %d' % len(train_set.image_ids))
# Out:
# ./dataset_train2\train\via_region_data.json
# 1
# Damages: [{'Light Scratches': True}]
# numids [1]
# 2
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 3
# Damages: [{'Moderate Dent': True}, {'Moderate Dent': True}]
# numids [2, 2]
# 4
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 5
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 6
# Damages: [{'Light Dent': True}]
# numids [2]
# 7
# Damages: [{'Moderate Dent': True}, {'Moderate Dent': True}]
# numids [2, 2]
# 8
# Damages: [{'Moderate Scratches': True}, {'Moderate Scratches': True}, {'Moderate Scratches': True}]
# numids [1, 1, 1]
# 9
# Damages: [{'Severe Dent': True}]
# numids [2]
# 10
# Damages: [{'Moderate Scratches': True}, {'Moderate Dent': True}, {'Light Dent': True}]
# numids [1, 2, 2]
# 11
# Damages: [{'Light Scratches': True}, {'Light Scratches': True}]
# numids [1, 1]
# 12
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 13
# Damages: [{'Light Scratches': True}]
# numids [1]
# 14
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 15
# Damages: [{'Moderate Dent': True}, {'Moderate Scratches': True}]
# numids [2, 1]
# 16
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 17
# Damages: [{'Moderate Scratches': True}, {'Moderate Scratches': True}]
# numids [1, 1]
# 18
# Damages: [{'Moderate Scratches': True}, {'Moderate Scratches': True}]
# numids [1, 1]
# 19
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 20
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 21
# Damages: [{'Moderate Dent': True}, {'Moderate Dent': True}]
# numids [2, 2]
# 22
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 23
# Damages: [{'Moderate Dent': True}, {'Moderate Dent': True}, {'Severe Dent': True}]
# numids [2, 2, 2]
# 24
# Damages: [{'Severe Dent': True}]
# numids [2]
# 25
# Damages: [{'Moderate Scratches': True}, {'Moderate Scratches': True}, {'Moderate Scratches': True}]
# numids [1, 1, 1]
# 26
# Damages: [{'Light Scratches': True}, {'Light Scratches': True}]
# numids [1, 1]
# 27
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 28
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 29
# Damages: [{'Moderate Dent': True}, {'Moderate Scratches': True}]
# numids [2, 1]
# 30
# Damages: [{'Moderate Scratches': True}, {'Moderate Dent': True}]
# numids [1, 2]
# 31
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 32
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 33
# Damages: [{'Moderate Dent': True}, {'Severe Dent': True}]
# numids [2, 2]
# 34
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 35
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 36
# Damages: [{'Moderate Dent': True}, {'Moderate Scratches': True}]
# numids [2, 1]
# 37
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 38
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 39
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 40
# Damages: [{'Severe Dent': True}]
# numids [2]
# 41
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 42
# Damages: [{'Severe Dent': True}, {'Light Dent': True}]
# numids [2, 2]
# 43
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 44
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 45
# Damages: [{'Moderate Dent': True}, {'Severe Dent': True}, {'Severe Dent': True}]
# numids [2, 2, 2]
# 46
# Damages: [{'Severe Dent': True}]
# numids [2]
# 47
# Damages: [{'Severe Dent': True}, {'Moderate Dent': True}]
# numids [2, 2]
# 48
# Damages: [{'Light Scratches': True}]
# numids [1]
# 49
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 50
# Damages: [{'Severe Dent': True}]
# numids [2]
# 51
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 52
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 53
# Damages: [{'Light Dent': True}]
# numids [2]
# 54
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 55
# Damages: [{'Moderate Scratches': True}, {'Moderate Scratches': True}]
# numids [1, 1]
# 56
# Damages: [{'Light Scratches': True}]
# numids [1]
# 57
# Damages: [{'Severe Dent': True}]
# numids [2]
# 58
# Damages: [{'Severe Dent': True}]
# numids [2]
# 59
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 60
# Damages: [{'Light Scratches': True}]
# numids [1]
# 61
# Damages: [{'Moderate Scratches': True}, {'Moderate Scratches': True}, {'Moderate Dent': True}, {'Moderate Scratches': True}]
# numids [1, 1, 2, 1]
# 62
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 63
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 64
# Damages: [{'Moderate Scratches': True}, {'Moderate Scratches': True}, {'Moderate Scratches': True}]
# numids [1, 1, 1]
# 65
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 66
# Damages: [{'Moderate Dent': True}, {'Moderate Dent': True}]
# numids [2, 2]
# 67
# Damages: [{'Moderate Dent': True}, {'Moderate Dent': True}]
# numids [2, 2]
# 68
# Damages: [{'Severe Dent': True}]
# numids [2]
# 69
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 70
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 71
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 72
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 73
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 74
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 75
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 76
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 77
# Damages: [{'Light Scratches': True}, {'Light Scratches': True}]
# numids [1, 1]
# 78
# Damages: [{'Severe Dent': True}, {'Light Scratches': True}]
# numids [2, 1]
# 79
# Damages: [{'Severe Dent': True}, {'Severe Dent': True}, {'Moderate Scratches': True}]
# numids [2, 2, 1]
# 80
# Damages: [{'Moderate Scratches': True}, {'Moderate Scratches': True}]
# numids [1, 1]
# 81
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 82
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 83
# Damages: [{'Moderate Scratches': True}, {'Moderate Scratches': True}]
# numids [1, 1]
# 84
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 85
# Damages: [{'Severe Dent': True}, {'Moderate Dent': True}, {'Severe Dent': True}]
# numids [2, 2, 2]
# 86
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 87
# Damages: [{'Moderate Dent': True}, {'Moderate Dent': True}]
# numids [2, 2]
# 88
# Damages: [{'Moderate Dent': True}, {'Severe Dent': True}, {'Moderate Dent': True}, {'Moderate Dent': True}]
# numids [2, 2, 2, 2]
# 89
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 90
# Damages: [{'Moderate Scratches': True}, {'Moderate Scratches': True}]
# numids [1, 1]
# 91
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 92
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 93
# Damages: [{'Severe Dent': True}]
# numids [2]
# 94
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 95
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 96
# Damages: [{'Moderate Dent': True}, {'Light Scratches': True}]
# numids [2, 1]
# 97
# Damages: [{'Severe Dent': True}, {'Severe Dent': True}]
# numids [2, 2]
# 98
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 99
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 100
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 101
# Damages: [{'Moderate Dent': True}, {'Moderate Dent': True}, {'Light Dent': True}]
# numids [2, 2, 2]
# 102
# Damages: [{'Light Dent': True}]
# numids [2]
# 103
# Damages: [{'Moderate Dent': True}, {'Moderate Dent': True}, {'Moderate Scratches': True}]
# numids [2, 2, 1]
# 104
# Damages: [{'Severe Dent': True}]
# numids [2]
# 105
# Damages: [{'Moderate Scratches': True}, {'Moderate Scratches': True}, {'Moderate Scratches': True}]
# numids [1, 1, 1]
# 106
# Damages: [{'Moderate Scratches': True}, {'Moderate Dent': True}]
# numids [1, 2]
# 107
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 108
# Damages: [{'Severe Dent': True}]
# numids [2]
# 109
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 110
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 111
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 112
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 113
# Damages: [{'Light Scratches': True}]
# numids [1]
# 114
# Damages: [{'Severe Dent': True}]
# numids [2]
# 115
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 116
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 117
# Damages: [{'Moderate Dent': True}, {'Moderate Dent': True}]
# numids [2, 2]
# 118
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 119
# Damages: [{'Moderate Dent': True}, {'Light Dent': True}]
# numids [2, 2]
# 120
# Damages: [{'Light Scratches': True}]
# numids [1]
# 121
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 122
# Damages: [{'Moderate Dent': True}]
# numids [2]
# 123
# Damages: [{'Light Dent': True}, {'Moderate Scratches': True}]
# numids [2, 1]
# 124
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# 125
# Damages: [{'Severe Dent': True}]
# numids [2]
# 126
# Damages: [{'Severe Dent': True}]
# numids [2]
# Train: 126

# %%
# load the test dataset
test_set = CustomDataset()
test_set.load_custom('./dataset_train2', 'val')
test_set.prepare()
print('Test: %d' % len(test_set.image_ids))
# Out:
# ./dataset_train2\val\via_region_data.json
# No annotation .DS_Store
# Damages: [{'Moderate Dent': True}]
# numids [2]
# Damages: [{'Moderate Scratches': True}, {'Moderate Scratches': True}, {'Light Scratches': True}, {'Moderate Scratches': True}]
# numids [1, 1, 1, 1]
# Damages: [{'Moderate Dent': True}]
# numids [2]
# Damages: [{'Light Dent': True}, {'Moderate Dent': True}]
# numids [2, 2]
# Damages: [{'Light Scratches': True}]
# numids [1]
# No annotation car135.jpg
# No annotation car138.jpg
# Damages: [{'Moderate Scratches': True}, {'Moderate Scratches': True}, {'Moderate Scratches': True}]
# numids [1, 1, 1]
# Damages: [{'Moderate Dent': True}]
# numids [2]
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# Damages: [{'Moderate Scratches': True}]
# numids [1]
# Damages: [{'Light Dent': True}]
# numids [2]
# Damages: [{'Light Dent': True}, {'Light Dent': True}]
# numids [2, 2]
# Damages: [{'Moderate Dent': True}]
# numids [2]
# No annotation via_region_data.json
# Test: 13

# %%
# create config
cfg = PredictionConfig()
# define the model
model = MaskRCNN(mode='inference', model_dir='./', config=cfg)
# Out:
# WARNING:tensorflow:From C:\Users\niels\miniconda3\envs\mlvc\lib\site-packages\keras\backend\tensorflow_backend.py:508: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\niels\miniconda3\envs\mlvc\lib\site-packages\keras\backend\tensorflow_backend.py:68: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\niels\miniconda3\envs\mlvc\lib\site-packages\keras\backend\tensorflow_backend.py:3837: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\niels\miniconda3\envs\mlvc\lib\site-packages\keras\backend\tensorflow_backend.py:3661: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\niels\miniconda3\envs\mlvc\lib\site-packages\keras\backend\tensorflow_backend.py:1944: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From d:\CS Projects\insurtech\Insurtech-CV\Mask_RCNN\mrcnn\model.py:341: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From d:\CS Projects\insurtech\Insurtech-CV\Mask_RCNN\mrcnn\model.py:399: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From d:\CS Projects\insurtech\Insurtech-CV\Mask_RCNN\mrcnn\model.py:423: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# WARNING:tensorflow:From d:\CS Projects\insurtech\Insurtech-CV\Mask_RCNN\mrcnn\model.py:720: The name tf.sets.set_intersection is deprecated. Please use tf.sets.intersection instead.
#
# WARNING:tensorflow:From d:\CS Projects\insurtech\Insurtech-CV\Mask_RCNN\mrcnn\model.py:722: The name tf.sparse_tensor_to_dense is deprecated. Please use tf.sparse.to_dense instead.
#
# WARNING:tensorflow:From d:\CS Projects\insurtech\Insurtech-CV\Mask_RCNN\mrcnn\model.py:772: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.

# %%
# Loading the COCO weights
COCO_WEIGHTS_PATH = "./mask_rcnn_damage_0034.h5"

model.load_weights(COCO_WEIGHTS_PATH, by_name=True)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\miniconda3\envs\mlvc\lib\site-packages\tensorflow_core\python\framework\ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1606   try:
# -> 1607     c_op = c_api.TF_FinishOperation(op_desc)
#    1608   except errors.InvalidArgumentError as e:
#
# InvalidArgumentError: Dimension 1 in both shapes must be equal, but are 12 and 16. Shapes are [1024,12] and [1024,16]. for 'Assign_682' (op: 'Assign') with input shapes: [1024,12], [1024,16].
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7704/2704834182.py in <module>
#       2 COCO_WEIGHTS_PATH = "./mask_rcnn_damage_0034.h5"
#       3
# ----> 4 model.load_weights(COCO_WEIGHTS_PATH, by_name=True)
#
# d:\CS Projects\insurtech\Insurtech-CV\Mask_RCNN\mrcnn\model.py in load_weights(self, filepath, by_name, exclude)
#    2128
#    2129         if by_name:
# -> 2130             saving.load_weights_from_hdf5_group_by_name(f, layers)
#    2131         else:
#    2132             saving.load_weights_from_hdf5_group(f, layers)
#
# ~\miniconda3\envs\mlvc\lib\site-packages\keras\engine\topology.py in load_weights_from_hdf5_group_by_name(f, layers, skip_mismatch, reshape)
#    3477                                             weight_values[i]))
#    3478
# -> 3479     K.batch_set_value(weight_value_tuples)
#
# ~\miniconda3\envs\mlvc\lib\site-packages\keras\backend\tensorflow_backend.py in batch_set_value(tuples)
#    2370                 assign_placeholder = tf.placeholder(tf_dtype,
#    2371                                                     shape=value.shape)
# -> 2372                 assign_op = x.assign(assign_placeholder)
#    2373                 x._assign_placeholder = assign_placeholder
#    2374                 x._assign_op = assign_op
#
# ~\miniconda3\envs\mlvc\lib\site-packages\tensorflow_core\python\ops\variables.py in assign(self, value, use_locking, name, read_value)
#    2065     """
#    2066     assign = state_ops.assign(
# -> 2067         self._variable, value, use_locking=use_locking, name=name)
#    2068     if read_value:
#    2069       return assign
#
# ~\miniconda3\envs\mlvc\lib\site-packages\tensorflow_core\python\ops\state_ops.py in assign(ref, value, validate_shape, use_locking, name)
#     225     return gen_state_ops.assign(
#     226         ref, value, use_locking=use_locking, name=name,
# --> 227         validate_shape=validate_shape)
#     228   return ref.assign(value, name=name)
#     229
#
# ~\miniconda3\envs\mlvc\lib\site-packages\tensorflow_core\python\ops\gen_state_ops.py in assign(ref, value, validate_shape, use_locking, name)
#      64   _, _, _op = _op_def_lib._apply_op_helper(
#      65         "Assign", ref=ref, value=value, validate_shape=validate_shape,
# ---> 66                   use_locking=use_locking, name=name)
#      67   _result = _op.outputs[:]
#      68   _inputs_flat = _op.inputs
#
# ~\miniconda3\envs\mlvc\lib\site-packages\tensorflow_core\python\framework\op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     792         op = g.create_op(op_type_name, inputs, dtypes=None, name=scope,
#     793                          input_types=input_types, attrs=attr_protos,
# --> 794                          op_def=op_def)
#     795
#     796       # Conditionally invoke tfdbg v2's op callback(s).
#
# ~\miniconda3\envs\mlvc\lib\site-packages\tensorflow_core\python\util\deprecation.py in new_func(*args, **kwargs)
#     505                 'in a future version' if date is None else ('after %s' % date),
#     506                 instructions)
# --> 507       return func(*args, **kwargs)
#     508
#     509     doc = _add_deprecated_arg_notice_to_docstring(
#
# ~\miniconda3\envs\mlvc\lib\site-packages\tensorflow_core\python\framework\ops.py in create_op(***failed resolving arguments***)
#    3355         raise TypeError("Input #%d is not a tensor: %s" % (idx, a))
#    3356     return self._create_op_internal(op_type, inputs, dtypes, input_types, name,
# -> 3357                                     attrs, op_def, compute_device)
#    3358
#    3359   def _create_op_internal(
#
# ~\miniconda3\envs\mlvc\lib\site-packages\tensorflow_core\python\framework\ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3424           input_types=input_types,
#    3425           original_op=self._default_original_op,
# -> 3426           op_def=op_def)
#    3427       self._create_op_helper(ret, compute_device=compute_device)
#    3428     return ret
#
# ~\miniconda3\envs\mlvc\lib\site-packages\tensorflow_core\python\framework\ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1768           op_def, inputs, node_def.attr)
#    1769       self._c_op = _create_c_op(self._graph, node_def, grouped_inputs,
# -> 1770                                 control_input_ops)
#    1771     # pylint: enable=protected-access
#    1772
#
# ~\miniconda3\envs\mlvc\lib\site-packages\tensorflow_core\python\framework\ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1608   except errors.InvalidArgumentError as e:
#    1609     # Convert to ValueError for backwards compatibility.
# -> 1610     raise ValueError(str(e))
#    1611
#    1612   return c_op
#
# ValueError: Dimension 1 in both shapes must be equal, but are 12 and 16. Shapes are [1024,12] and [1024,16]. for 'Assign_682' (op: 'Assign') with input shapes: [1024,12], [1024,16].

# %%
count = 0

dataset = test_set

for image_id in dataset.image_ids:
    
    # Only show 5 pics coz takes quite some time
    if count == 20:
        break
    # load image, bounding boxes and masks for the image id
    image, image_meta, gt_class_id, gt_bbox, gt_mask = load_image_gt(dataset, cfg, image_id, use_mini_mask=False)

    # display ground truth image with masks and bounding boxes
    fig = plt.figure()
    axes1 = fig.add_axes([0, 0, 1, 1])
    axes2 = fig.add_axes([1, 0, 1, 1])
    display_instances(image, gt_bbox, gt_mask, gt_class_id, train_set.class_names, ax = axes1, title='Ground Truth')


    # convert pixel values (e.g. center)
    scaled_image = mold_image(image, cfg)
    # convert image into one sample
    sample = expand_dims(scaled_image, 0)
    # make prediction
    yhat = model.detect(sample, verbose=0)
    # extract results for first sample
    r = yhat[0]
    # calculate statistics, including AP
    AP, _, _, _ = compute_ap(gt_bbox, gt_class_id, gt_mask, r["rois"], r["class_ids"], r["scores"], r['masks'])

    # Getting predicted values from r
    pred_class_id = r['class_ids']
    pred_mask = r['masks']
    pred_bbox = extract_bboxes(pred_mask)
    # display predicted image with masks and bounding boxes
    display_instances(image, pred_bbox, pred_mask, pred_class_id, train_set.class_names, scores=r['scores'], ax=axes2, title='Predicted')

    print(f'Ground truth class id : {gt_class_id}')
    print(f'Predicted class id : {r["class_ids"]}')
    print(f"Ground truth mask shape is {gt_mask.shape}")
    print(f"Predicted mask shape is {r['masks'].shape}")

    print(f'AP is {AP}')
    plt.show()
# Out:
# Ground truth class id : [2]
# Predicted class id : [2]
# Ground truth mask shape is (1024, 1024, 1)
# Predicted mask shape is (1024, 1024, 1)
# AP is 0.0
# Ground truth class id : [1 1 1 1]
# Predicted class id : [1]
# Ground truth mask shape is (1024, 1024, 4)
# Predicted mask shape is (1024, 1024, 1)
# AP is 0.25
# *** No instances to display ***
#
# Ground truth class id : [2]
# Predicted class id : []
# Ground truth mask shape is (1024, 1024, 1)
# Predicted mask shape is (1024, 1024, 0)
# AP is 0.0
# Ground truth class id : [2 2]
# Predicted class id : [2]
# Ground truth mask shape is (1024, 1024, 2)
# Predicted mask shape is (1024, 1024, 1)
# AP is 0.5
# Ground truth class id : [1]
# Predicted class id : [1]
# Ground truth mask shape is (1024, 1024, 1)
# Predicted mask shape is (1024, 1024, 1)
# AP is 1.0
# Ground truth class id : [1 1 1]
# Predicted class id : [1 1]
# Ground truth mask shape is (1024, 1024, 3)
# Predicted mask shape is (1024, 1024, 2)
# AP is 0.6666666865348816
# Ground truth class id : [2]
# Predicted class id : [2]
# Ground truth mask shape is (1024, 1024, 1)
# Predicted mask shape is (1024, 1024, 1)
# AP is 0.0
# Ground truth class id : [1]
# Predicted class id : [1]
# Ground truth mask shape is (1024, 1024, 1)
# Predicted mask shape is (1024, 1024, 1)
# AP is 1.0
# Ground truth class id : [1]
# Predicted class id : [1]
# Ground truth mask shape is (1024, 1024, 1)
# Predicted mask shape is (1024, 1024, 1)
# AP is 1.0
# Ground truth class id : [1]
# Predicted class id : [1]
# Ground truth mask shape is (1024, 1024, 1)
# Predicted mask shape is (1024, 1024, 1)
# AP is 0.0
# *** No instances to display ***
#
# Ground truth class id : [2]
# Predicted class id : []
# Ground truth mask shape is (1024, 1024, 1)
# Predicted mask shape is (1024, 1024, 0)
# AP is 0.0
# Ground truth class id : [2 2]
# Predicted class id : [2]
# Ground truth mask shape is (1024, 1024, 2)
# Predicted mask shape is (1024, 1024, 1)
# AP is 0.0
# Ground truth class id : [2]
# Predicted class id : [2 2 2]
# Ground truth mask shape is (1024, 1024, 1)
# Predicted mask shape is (1024, 1024, 3)
# AP is 1.0

# %%
# evaluate model on training dataset
train_mAP = evaluate_model(train_set, model, cfg)
print("Train mAP: %.3f" % train_mAP)
# Out:
# This car is problem ! 89
# Train mAP: 0.840

# %%
# evaluate model on test dataset
test_mAP = evaluate_model(test_set, model, cfg)
print("Test mAP: %.3f" % test_mAP)
# Out:
# Test mAP: 0.417
