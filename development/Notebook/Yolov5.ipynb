# %% [markdown]
# # Annotations: To YOLOV5 Format

# %%
import json
import yaml
from bidict import bidict
from PIL import Image

# %% [markdown]
# ## Configs

# %%
labels = bidict({"Front": 0, "Side": 1, "Back": 2})
img_dir = os.path.join("../Processing/Dataset_v1")
input_json = os.path.join("./yolov5_1/", "YoloAnnotationV2.json")
output_dir = os.path.join("./yolov5_1/", "YoloAnnotation/")

# %% [markdown]
# ## Prep. Directories

# %%
assert len(os.listdir(img_dir)) > 0

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %% [markdown]
# ## Get Formatted Annotations
#
# To check correctness, make sure that for image car99.jpg, values are close to these:
#
# 0 0.6430288461538461 0.39302884615384615 0.7115384615384616 0.78125
#
# 2 0.19230769230769232 0.3076923076923077 0.18509615384615385 0.6057692307692307

# %%
annotations1 = json.load(open(input_json))
annotations = list(annotations1.values())[1]

# %%
missedAnnotation = 0
for item in annotations.keys(): 
    element = annotations[item]

    regions = element["regions"]
    filename = element["filename"]

    # Needed to normalise coordinates
    im = Image.open(os.path.join(img_dir, filename))
    img_width, img_height = im.size

    yolo_annotations = []    
    print("Img Name: ", filename)
    print("-----------------------------------")
    for region in regions: 
        if region["region_attributes"]:
            print("Region: ", region["shape_attributes"]) # Properties: x, y, width, height
            class_name = region["region_attributes"]["Car Side"]

            # From Format: x, y, w, h measured from top left coordinates
            x = region["shape_attributes"]["x"]
            y = region["shape_attributes"]["y"]
            w = region["shape_attributes"]["width"]
            h = region["shape_attributes"]["height"]

            # To Format: x, y, w, h measured from center coordinates
            x_center = x + w/2
            y_center = y + h/2

            ## Normalizing for YOLO Format: 
            print(x)
            yolo_format = [ labels[class_name], x_center / img_width, y_center / img_height, w / img_width, h / img_height ]

            print("Class Label: ", labels[class_name])
            print("Yolo Annotation: ", yolo_format)
            yolo_annotations.append(yolo_format)
        else: 
            missedAnnotation +=1
    
    # Saving to txt
    yolo_annotations = [" ".join([str(e) for e in yolo_format]) for yolo_format in yolo_annotations]
    with open(os.path.join(output_dir, filename.split('.')[0]+'.txt'), 'w') as f:
        f.writelines("\n".join(yolo_annotations))
    print("-----------------------------------")
print(missedAnnotation)
# Out:
# Img Name:  car99.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 294, 'y': 2, 'width': 728, 'height': 800}
# 294
# Class Label:  2
# Yolo Annotation:  [2, 0.642578125, 0.392578125, 0.7109375, 0.78125]
# Region:  {'name': 'rect', 'x': 103, 'y': 5, 'width': 189, 'height': 620}
# 103
# Class Label:  1
# Yolo Annotation:  [1, 0.19287109375, 0.3076171875, 0.1845703125, 0.60546875]
# -----------------------------------
# Img Name:  car98.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 51, 'y': 279, 'width': 634, 'height': 611}
# 51
# Class Label:  0
# Yolo Annotation:  [0, 0.359375, 0.57080078125, 0.619140625, 0.5966796875]
# Region:  {'name': 'rect', 'x': 477, 'y': 301, 'width': 470, 'height': 372}
# 477
# Class Label:  1
# Yolo Annotation:  [1, 0.6953125, 0.4755859375, 0.458984375, 0.36328125]
# Region:  {'name': 'rect', 'x': 305, 'y': 195, 'width': 113, 'height': 89}
# 305
# Class Label:  0
# Yolo Annotation:  [0, 0.35302734375, 0.23388671875, 0.1103515625, 0.0869140625]
# -----------------------------------
# Img Name:  car97.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 87, 'y': 320, 'width': 802, 'height': 654}
# 87
# Class Label:  0
# Yolo Annotation:  [0, 0.4765625, 0.6318359375, 0.783203125, 0.638671875]
# -----------------------------------
# Img Name:  car96.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 97, 'y': 249, 'width': 550, 'height': 651}
# 97
# Class Label:  1
# Yolo Annotation:  [1, 0.36328125, 0.56103515625, 0.537109375, 0.6357421875]
# Region:  {'name': 'rect', 'x': 612, 'y': 330, 'width': 324, 'height': 568}
# 612
# Class Label:  2
# Yolo Annotation:  [2, 0.755859375, 0.599609375, 0.31640625, 0.5546875]
# Region:  {'name': 'rect', 'x': 0, 'y': 12, 'width': 149, 'height': 208}
# 0
# Class Label:  2
# Yolo Annotation:  [2, 0.07275390625, 0.11328125, 0.1455078125, 0.203125]
# -----------------------------------
# Img Name:  car95.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 7, 'y': 29, 'width': 745, 'height': 750}
# 7
# Class Label:  0
# Yolo Annotation:  [0, 0.37060546875, 0.39453125, 0.7275390625, 0.732421875]
# -----------------------------------
# Img Name:  car94.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 8, 'y': 331, 'width': 355, 'height': 522}
# 8
# Class Label:  0
# Yolo Annotation:  [0, 0.18115234375, 0.578125, 0.3466796875, 0.509765625]
# Region:  {'name': 'rect', 'x': 362, 'y': 311, 'width': 654, 'height': 462}
# 362
# Class Label:  1
# Yolo Annotation:  [1, 0.6728515625, 0.529296875, 0.638671875, 0.451171875]
# -----------------------------------
# Img Name:  car93.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 18, 'y': 208, 'width': 528, 'height': 806}
# 18
# Class Label:  0
# Yolo Annotation:  [0, 0.275390625, 0.5966796875, 0.515625, 0.787109375]
# Region:  {'name': 'rect', 'x': 567, 'y': 137, 'width': 435, 'height': 597}
# 567
# Class Label:  1
# Yolo Annotation:  [1, 0.76611328125, 0.42529296875, 0.4248046875, 0.5830078125]
# Region:  {'name': 'rect', 'x': 905, 'y': 12, 'width': 114, 'height': 140}
# 905
# Class Label:  1
# Yolo Annotation:  [1, 0.939453125, 0.080078125, 0.111328125, 0.13671875]
# -----------------------------------
# Img Name:  car92.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 13, 'y': 10, 'width': 1001, 'height': 1006}
# 13
# Class Label:  1
# Yolo Annotation:  [1, 0.50146484375, 0.5009765625, 0.9775390625, 0.982421875]
# -----------------------------------
# Img Name:  car91.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 107, 'y': 354, 'width': 796, 'height': 499}
# 107
# Class Label:  1
# Yolo Annotation:  [1, 0.4931640625, 0.58935546875, 0.77734375, 0.4873046875]
# Region:  {'name': 'rect', 'x': 916, 'y': 381, 'width': 103, 'height': 471}
# 916
# Class Label:  0
# Yolo Annotation:  [0, 0.94482421875, 0.60205078125, 0.1005859375, 0.4599609375]
# -----------------------------------
# Img Name:  car90.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 6, 'y': 8, 'width': 808, 'height': 903}
# 6
# Class Label:  2
# Yolo Annotation:  [2, 0.400390625, 0.44873046875, 0.7890625, 0.8818359375]
# Region:  {'name': 'rect', 'x': 813, 'y': 10, 'width': 206, 'height': 507}
# 813
# Class Label:  1
# Yolo Annotation:  [1, 0.89453125, 0.25732421875, 0.201171875, 0.4951171875]
# -----------------------------------
# Img Name:  car9.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 10, 'y': 4, 'width': 392, 'height': 235}
# 10
# Class Label:  2
# Yolo Annotation:  [2, 0.4951923076923077, 0.3894230769230769, 0.9423076923076923, 0.7532051282051282]
# -----------------------------------
# Img Name:  car89.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 187, 'y': 158, 'width': 825, 'height': 843}
# 187
# Class Label:  2
# Yolo Annotation:  [2, 0.58544921875, 0.56591796875, 0.8056640625, 0.8232421875]
# Region:  {'name': 'rect', 'x': 52, 'y': 6, 'width': 118, 'height': 825}
# 52
# Class Label:  1
# Yolo Annotation:  [1, 0.1083984375, 0.40869140625, 0.115234375, 0.8056640625]
# -----------------------------------
# Img Name:  car88.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 29, 'y': 212, 'width': 833, 'height': 793}
# 29
# Class Label:  2
# Yolo Annotation:  [2, 0.43505859375, 0.59423828125, 0.8134765625, 0.7744140625]
# Region:  {'name': 'rect', 'x': 872, 'y': 280, 'width': 142, 'height': 441}
# 872
# Class Label:  1
# Yolo Annotation:  [1, 0.9208984375, 0.48876953125, 0.138671875, 0.4306640625]
# -----------------------------------
# Img Name:  car87.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 21, 'y': 11, 'width': 730, 'height': 886}
# 21
# Class Label:  0
# Yolo Annotation:  [0, 0.376953125, 0.443359375, 0.712890625, 0.865234375]
# -----------------------------------
# Img Name:  car86.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 562, 'y': 23, 'width': 442, 'height': 825}
# 562
# Class Label:  0
# Yolo Annotation:  [0, 0.7646484375, 0.42529296875, 0.431640625, 0.8056640625]
# Region:  {'name': 'rect', 'x': 4, 'y': 5, 'width': 385, 'height': 653}
# 4
# Class Label:  1
# Yolo Annotation:  [1, 0.19189453125, 0.32373046875, 0.3759765625, 0.6376953125]
# -----------------------------------
# Img Name:  car85.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 86, 'y': 167, 'width': 737, 'height': 457}
# 86
# Class Label:  2
# Yolo Annotation:  [2, 0.44384765625, 0.38623046875, 0.7197265625, 0.4462890625]
# Region:  {'name': 'rect', 'x': 746, 'y': 115, 'width': 246, 'height': 276}
# 746
# Class Label:  1
# Yolo Annotation:  [1, 0.8486328125, 0.2470703125, 0.240234375, 0.26953125]
# Region:  {'name': 'rect', 'x': 78, 'y': 79, 'width': 76, 'height': 62}
# 78
# Class Label:  1
# Yolo Annotation:  [1, 0.11328125, 0.107421875, 0.07421875, 0.060546875]
# -----------------------------------
# Img Name:  car84.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 12, 'y': 64, 'width': 516, 'height': 854}
# 12
# Class Label:  2
# Yolo Annotation:  [2, 0.263671875, 0.4794921875, 0.50390625, 0.833984375]
# Region:  {'name': 'rect', 'x': 526, 'y': 332, 'width': 442, 'height': 370}
# 526
# Class Label:  1
# Yolo Annotation:  [1, 0.7294921875, 0.5048828125, 0.431640625, 0.361328125]
# -----------------------------------
# Img Name:  car83.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 0, 'y': 5, 'width': 639, 'height': 898}
# 0
# Class Label:  0
# Yolo Annotation:  [0, 0.31201171875, 0.443359375, 0.6240234375, 0.876953125]
# Region:  {'name': 'rect', 'x': 657, 'y': 10, 'width': 150, 'height': 502}
# 657
# Class Label:  1
# Yolo Annotation:  [1, 0.71484375, 0.2548828125, 0.146484375, 0.490234375]
# -----------------------------------
# Img Name:  car82.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 21, 'y': 256, 'width': 556, 'height': 584}
# 21
# Class Label:  0
# Yolo Annotation:  [0, 0.2919921875, 0.53515625, 0.54296875, 0.5703125]
# Region:  {'name': 'rect', 'x': 625, 'y': 217, 'width': 381, 'height': 434}
# 625
# Class Label:  1
# Yolo Annotation:  [1, 0.79638671875, 0.423828125, 0.3720703125, 0.423828125]
# Region:  {'name': 'rect', 'x': 298, 'y': 75, 'width': 126, 'height': 90}
# 298
# Class Label:  0
# Yolo Annotation:  [0, 0.3525390625, 0.1171875, 0.123046875, 0.087890625]
# Region:  {'name': 'rect', 'x': 188, 'y': 62, 'width': 119, 'height': 81}
# 188
# Class Label:  0
# Yolo Annotation:  [0, 0.24169921875, 0.10009765625, 0.1162109375, 0.0791015625]
# -----------------------------------
# Img Name:  car81.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 115, 'y': 130, 'width': 894, 'height': 865}
# 115
# Class Label:  0
# Yolo Annotation:  [0, 0.548828125, 0.54931640625, 0.873046875, 0.8447265625]
# -----------------------------------
# Img Name:  car80.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 302, 'y': 191, 'width': 118, 'height': 93}
# 302
# Class Label:  0
# Yolo Annotation:  [0, 0.3525390625, 0.23193359375, 0.115234375, 0.0908203125]
# Region:  {'name': 'rect', 'x': 74, 'y': 284, 'width': 645, 'height': 636}
# 74
# Class Label:  0
# Yolo Annotation:  [0, 0.38720703125, 0.587890625, 0.6298828125, 0.62109375]
# Region:  {'name': 'rect', 'x': 539, 'y': 297, 'width': 425, 'height': 354}
# 539
# Class Label:  1
# Yolo Annotation:  [1, 0.73388671875, 0.462890625, 0.4150390625, 0.345703125]
# -----------------------------------
# Img Name:  car8.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 5, 'y': 2, 'width': 360, 'height': 257}
# 5
# Class Label:  0
# Yolo Annotation:  [0, 0.4625, 0.4156050955414013, 0.9, 0.8184713375796179]
# -----------------------------------
# Img Name:  car79.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 25, 'y': 424, 'width': 520, 'height': 562}
# 25
# Class Label:  2
# Yolo Annotation:  [2, 0.2783203125, 0.6884765625, 0.5078125, 0.548828125]
# Region:  {'name': 'rect', 'x': 427, 'y': 290, 'width': 527, 'height': 475}
# 427
# Class Label:  1
# Yolo Annotation:  [1, 0.67431640625, 0.51513671875, 0.5146484375, 0.4638671875]
# -----------------------------------
# Img Name:  car78.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 15, 'y': 164, 'width': 865, 'height': 836}
# 15
# Class Label:  0
# Yolo Annotation:  [0, 0.43701171875, 0.568359375, 0.8447265625, 0.81640625]
# -----------------------------------
# Img Name:  car77.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 5, 'y': 319, 'width': 448, 'height': 703}
# 5
# Class Label:  1
# Yolo Annotation:  [1, 0.2236328125, 0.65478515625, 0.4375, 0.6865234375]
# Region:  {'name': 'rect', 'x': 475, 'y': 330, 'width': 533, 'height': 532}
# 475
# Class Label:  1
# Yolo Annotation:  [1, 0.72412109375, 0.58203125, 0.5205078125, 0.51953125]
# -----------------------------------
# Img Name:  car76.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 7, 'y': 128, 'width': 959, 'height': 714}
# 7
# Class Label:  1
# Yolo Annotation:  [1, 0.47509765625, 0.4736328125, 0.9365234375, 0.697265625]
# -----------------------------------
# Img Name:  car75.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 6, 'y': 6, 'width': 713, 'height': 939}
# 6
# Class Label:  0
# Yolo Annotation:  [0, 0.35400390625, 0.46435546875, 0.6962890625, 0.9169921875]
# -----------------------------------
# Img Name:  car74.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 13, 'y': 15, 'width': 740, 'height': 808}
# 13
# Class Label:  2
# Yolo Annotation:  [2, 0.3740234375, 0.4091796875, 0.72265625, 0.7890625]
# Region:  {'name': 'rect', 'x': 782, 'y': 18, 'width': 239, 'height': 635}
# 782
# Class Label:  1
# Yolo Annotation:  [1, 0.88037109375, 0.32763671875, 0.2333984375, 0.6201171875]
# -----------------------------------
# Img Name:  car73.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 99, 'y': 220, 'width': 837, 'height': 789}
# 99
# Class Label:  1
# Yolo Annotation:  [1, 0.50537109375, 0.60009765625, 0.8173828125, 0.7705078125]
# -----------------------------------
# Img Name:  car72.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 13, 'y': 218, 'width': 994, 'height': 590}
# 13
# Class Label:  1
# Yolo Annotation:  [1, 0.498046875, 0.5009765625, 0.970703125, 0.576171875]
# -----------------------------------
# Img Name:  car71.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 20, 'y': 152, 'width': 788, 'height': 864}
# 20
# Class Label:  1
# Yolo Annotation:  [1, 0.404296875, 0.5703125, 0.76953125, 0.84375]
# -----------------------------------
# Img Name:  car70.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 92, 'y': 15, 'width': 926, 'height': 658}
# 92
# Class Label:  2
# Yolo Annotation:  [2, 0.5419921875, 0.3359375, 0.904296875, 0.642578125]
# -----------------------------------
# Img Name:  car7.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 206, 'y': 20, 'width': 809, 'height': 612}
# 206
# Class Label:  0
# Yolo Annotation:  [0, 0.59619140625, 0.49319213313161875, 0.7900390625, 0.9258698940998488]
# -----------------------------------
# Img Name:  car69.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 16, 'y': 61, 'width': 929, 'height': 919}
# 16
# Class Label:  0
# Yolo Annotation:  [0, 0.46923828125, 0.50830078125, 0.9072265625, 0.8974609375]
# -----------------------------------
# Img Name:  car68.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 184, 'y': 15, 'width': 820, 'height': 1000}
# 184
# Class Label:  2
# Yolo Annotation:  [2, 0.580078125, 0.5029296875, 0.80078125, 0.9765625]
# -----------------------------------
# Img Name:  car67.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 2, 'y': 183, 'width': 988, 'height': 582}
# 2
# Class Label:  1
# Yolo Annotation:  [1, 0.484375, 0.462890625, 0.96484375, 0.568359375]
# -----------------------------------
# Img Name:  car66.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 26, 'y': 211, 'width': 708, 'height': 793}
# 26
# Class Label:  1
# Yolo Annotation:  [1, 0.37109375, 0.59326171875, 0.69140625, 0.7744140625]
# -----------------------------------
# Img Name:  car65.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 9, 'y': 5, 'width': 702, 'height': 721}
# 9
# Class Label:  1
# Yolo Annotation:  [1, 0.3515625, 0.35693359375, 0.685546875, 0.7041015625]
# Region:  {'name': 'rect', 'x': 620, 'y': 8, 'width': 402, 'height': 856}
# 620
# Class Label:  0
# Yolo Annotation:  [0, 0.8017578125, 0.42578125, 0.392578125, 0.8359375]
# -----------------------------------
# Img Name:  car64.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 10, 'y': 4, 'width': 994, 'height': 814}
# 10
# Class Label:  1
# Yolo Annotation:  [1, 0.4951171875, 0.4013671875, 0.970703125, 0.794921875]
# -----------------------------------
# Img Name:  car63.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 34, 'y': 10, 'width': 914, 'height': 914}
# 34
# Class Label:  0
# Yolo Annotation:  [0, 0.4794921875, 0.4560546875, 0.892578125, 0.892578125]
# -----------------------------------
# Img Name:  car62.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 29, 'y': 4, 'width': 968, 'height': 996}
# 29
# Class Label:  0
# Yolo Annotation:  [0, 0.5009765625, 0.490234375, 0.9453125, 0.97265625]
# -----------------------------------
# Img Name:  car61.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 6, 'y': 6, 'width': 651, 'height': 676}
# 6
# Class Label:  2
# Yolo Annotation:  [2, 0.32373046875, 0.3359375, 0.6357421875, 0.66015625]
# Region:  {'name': 'rect', 'x': 663, 'y': 8, 'width': 202, 'height': 504}
# 663
# Class Label:  1
# Yolo Annotation:  [1, 0.74609375, 0.25390625, 0.197265625, 0.4921875]
# -----------------------------------
# Img Name:  car60.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 73, 'y': 18, 'width': 580, 'height': 825}
# 73
# Class Label:  1
# Yolo Annotation:  [1, 0.3544921875, 0.42041015625, 0.56640625, 0.8056640625]
# Region:  {'name': 'rect', 'x': 637, 'y': 27, 'width': 379, 'height': 933}
# 637
# Class Label:  2
# Yolo Annotation:  [2, 0.80712890625, 0.48193359375, 0.3701171875, 0.9111328125]
# Region:  {'name': 'rect', 'x': 2, 'y': 11, 'width': 127, 'height': 142}
# 2
# Class Label:  2
# Yolo Annotation:  [2, 0.06396484375, 0.080078125, 0.1240234375, 0.138671875]
# -----------------------------------
# Img Name:  car6.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 6, 'y': 6, 'width': 381, 'height': 264}
# 6
# Class Label:  0
# Yolo Annotation:  [0, 0.42717391304347824, 0.47586206896551725, 0.8282608695652174, 0.9103448275862069]
# -----------------------------------
# Img Name:  car59.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 78, 'y': 14, 'width': 167, 'height': 165}
# 78
# Class Label:  2
# Yolo Annotation:  [2, 0.6235521235521235, 0.49742268041237114, 0.6447876447876448, 0.8505154639175257]
# -----------------------------------
# Img Name:  car58.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 3, 'y': 4, 'width': 223, 'height': 229}
# 3
# Class Label:  2
# Yolo Annotation:  [2, 0.458, 0.474, 0.892, 0.916]
# -----------------------------------
# Img Name:  car57.jpg
# -----------------------------------
# -----------------------------------
# Img Name:  car56.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 10, 'y': 12, 'width': 631, 'height': 255}
# 10
# Class Label:  1
# Yolo Annotation:  [1, 0.5007692307692307, 0.4982142857142857, 0.9707692307692307, 0.9107142857142857]
# -----------------------------------
# Img Name:  car55.jpg
# -----------------------------------
# -----------------------------------
# Img Name:  car54.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 0, 'y': 196, 'width': 588, 'height': 564}
# 0
# Class Label:  1
# Yolo Annotation:  [1, 0.287109375, 0.6223958333333334, 0.57421875, 0.734375]
# -----------------------------------
# Img Name:  car53.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 16, 'y': 26, 'width': 524, 'height': 359}
# 16
# Class Label:  1
# Yolo Annotation:  [1, 0.5110294117647058, 0.4858156028368794, 0.9632352941176471, 0.8486997635933806]
# -----------------------------------
# Img Name:  car52.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 26, 'y': 12, 'width': 361, 'height': 282}
# 26
# Class Label:  0
# Yolo Annotation:  [0, 0.51625, 0.5083056478405316, 0.9025, 0.9368770764119602]
# -----------------------------------
# Img Name:  car51.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 6, 'y': 27, 'width': 182, 'height': 156}
# 6
# Class Label:  2
# Yolo Annotation:  [2, 0.3745173745173745, 0.5412371134020618, 0.7027027027027027, 0.8041237113402062]
# -----------------------------------
# Img Name:  car50.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 3, 'y': 4, 'width': 415, 'height': 600}
# 3
# Class Label:  0
# Yolo Annotation:  [0, 0.43854166666666666, 0.475, 0.8645833333333334, 0.9375]
# -----------------------------------
# Img Name:  car5.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 2, 'y': 3, 'width': 504, 'height': 394}
# 2
# Class Label:  1
# Yolo Annotation:  [1, 0.46691176470588236, 0.4728132387706856, 0.9264705882352942, 0.9314420803782506]
# -----------------------------------
# Img Name:  car49.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 16, 'y': 4, 'width': 191, 'height': 138}
# 16
# Class Label:  0
# Yolo Annotation:  [0, 0.3655737704918033, 0.44242424242424244, 0.6262295081967213, 0.8363636363636363]
# -----------------------------------
# Img Name:  car48.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 45, 'y': 5, 'width': 794, 'height': 306}
# 45
# Class Label:  1
# Yolo Annotation:  [1, 0.5212264150943396, 0.40512820512820513, 0.9363207547169812, 0.7846153846153846]
# -----------------------------------
# Img Name:  car47.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 26, 'y': 36, 'width': 556, 'height': 334}
# 26
# Class Label:  1
# Yolo Annotation:  [1, 0.5066666666666667, 0.5087719298245614, 0.9266666666666666, 0.8370927318295739]
# -----------------------------------
# Img Name:  car46.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 10, 'y': 42, 'width': 231, 'height': 171}
# 10
# Class Label:  1
# Yolo Annotation:  [1, 0.41833333333333333, 0.5666666666666667, 0.77, 0.76]
# -----------------------------------
# Img Name:  car45.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 48, 'y': 7, 'width': 206, 'height': 183}
# 48
# Class Label:  0
# Yolo Annotation:  [0, 0.5852713178294574, 0.5051282051282051, 0.7984496124031008, 0.9384615384615385]
# -----------------------------------
# Img Name:  car44.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 33, 'y': 73, 'width': 317, 'height': 190}
# 33
# Class Label:  1
# Yolo Annotation:  [1, 0.5334261838440112, 0.5384615384615384, 0.883008356545961, 0.6089743589743589]
# -----------------------------------
# Img Name:  car43.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 314, 'y': 28, 'width': 1275, 'height': 1149}
# 314
# Class Label:  1
# Yolo Annotation:  [1, 0.5946875, 0.5020833333333333, 0.796875, 0.9575]
# -----------------------------------
# Img Name:  car42.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 41, 'y': 25, 'width': 721, 'height': 913}
# 41
# Class Label:  1
# Yolo Annotation:  [1, 0.5227864583333334, 0.47021484375, 0.9388020833333334, 0.8916015625]
# -----------------------------------
# Img Name:  car41.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 11, 'y': 6, 'width': 253, 'height': 168}
# 11
# Class Label:  0
# Yolo Annotation:  [0, 0.5, 0.4918032786885246, 0.92, 0.9180327868852459]
# -----------------------------------
# Img Name:  car40.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 62, 'y': 10, 'width': 328, 'height': 281}
# 62
# Class Label:  0
# Yolo Annotation:  [0, 0.565, 0.5016666666666667, 0.82, 0.9366666666666666]
# -----------------------------------
# Img Name:  car4.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 229, 'y': 159, 'width': 659, 'height': 181}
# 229
# Class Label:  1
# Yolo Annotation:  [1, 0.5805613305613305, 0.6070559610705596, 0.685031185031185, 0.44038929440389296]
# Region:  {'name': 'rect', 'x': 56, 'y': 194, 'width': 132, 'height': 151}
# 56
# Class Label:  0
# Yolo Annotation:  [0, 0.12681912681912683, 0.6557177615571776, 0.13721413721413722, 0.36739659367396593]
# Region:  {'name': 'rect', 'x': 865, 'y': 134, 'width': 96, 'height': 161}
# 865
# Class Label:  2
# Yolo Annotation:  [2, 0.9490644490644491, 0.5218978102189781, 0.0997920997920998, 0.39172749391727496]
# -----------------------------------
# Img Name:  car39.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 70, 'y': 271, 'width': 1374, 'height': 1609}
# 70
# Class Label:  0
# Yolo Annotation:  [0, 0.4928385416666667, 0.525146484375, 0.89453125, 0.78564453125]
# -----------------------------------
# Img Name:  car38.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 192, 'y': 69, 'width': 585, 'height': 455}
# 192
# Class Label:  2
# Yolo Annotation:  [2, 0.605625, 0.5562851782363978, 0.73125, 0.8536585365853658]
# -----------------------------------
# Img Name:  car37.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 25, 'y': 11, 'width': 273, 'height': 186}
# 25
# Class Label:  2
# Yolo Annotation:  [2, 0.5383333333333333, 0.4581497797356828, 0.91, 0.8193832599118943]
# -----------------------------------
# Img Name:  car36.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 199, 'y': 47, 'width': 548, 'height': 502}
# 199
# Class Label:  1
# Yolo Annotation:  [1, 0.6166883963494133, 0.5182608695652174, 0.7144719687092569, 0.8730434782608696]
# -----------------------------------
# Img Name:  car35.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 291, 'y': 16, 'width': 1178, 'height': 1067}
# 291
# Class Label:  1
# Yolo Annotation:  [1, 0.5866666666666667, 0.44857142857142857, 0.7853333333333333, 0.8710204081632653]
# -----------------------------------
# Img Name:  car34.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 53, 'y': 1, 'width': 262, 'height': 143}
# 53
# Class Label:  0
# Yolo Annotation:  [0, 0.5786163522012578, 0.4559748427672956, 0.8238993710691824, 0.89937106918239]
# -----------------------------------
# Img Name:  car33.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 2, 'y': 7, 'width': 172, 'height': 225}
# 2
# Class Label:  2
# Yolo Annotation:  [2, 0.44221105527638194, 0.4723320158102767, 0.864321608040201, 0.8893280632411067]
# -----------------------------------
# Img Name:  car32.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 38, 'y': 11, 'width': 219, 'height': 148}
# 38
# Class Label:  0
# Yolo Annotation:  [0, 0.5694980694980695, 0.4381443298969072, 0.8455598455598455, 0.7628865979381443]
# -----------------------------------
# Img Name:  car31.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 13, 'y': 27, 'width': 781, 'height': 471}
# 13
# Class Label:  1
# Yolo Annotation:  [1, 0.5050062578222778, 0.4934210526315789, 0.9774718397997497, 0.8853383458646616]
# -----------------------------------
# Img Name:  car30.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 179, 'y': 126, 'width': 617, 'height': 462}
# 179
# Class Label:  1
# Yolo Annotation:  [1, 0.609375, 0.595, 0.77125, 0.77]
# -----------------------------------
# Img Name:  car3.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 35, 'y': 20, 'width': 534, 'height': 466}
# 35
# Class Label:  1
# Yolo Annotation:  [1, 0.47634069400630913, 0.47026022304832715, 0.8422712933753943, 0.8661710037174721]
# -----------------------------------
# Img Name:  car29.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 1054, 'y': 204, 'width': 707, 'height': 1287}
# 1054
# Class Label:  2
# Yolo Annotation:  [2, 0.687255859375, 0.5517578125, 0.34521484375, 0.837890625]
# Region:  {'name': 'rect', 'x': 0, 'y': 174, 'width': 1065, 'height': 1336}
# 0
# Class Label:  1
# Yolo Annotation:  [1, 0.260009765625, 0.5481770833333334, 0.52001953125, 0.8697916666666666]
# Region:  {'name': 'rect', 'x': 1748, 'y': 7, 'width': 289, 'height': 227}
# 1748
# Class Label:  0
# Yolo Annotation:  [0, 0.924072265625, 0.07845052083333333, 0.14111328125, 0.14778645833333334]
# -----------------------------------
# Img Name:  car28.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 0, 'y': 105, 'width': 209, 'height': 142}
# 0
# Class Label:  2
# Yolo Annotation:  [2, 0.10205078125, 0.22916666666666666, 0.2041015625, 0.18489583333333334]
# Region:  {'name': 'rect', 'x': 11, 'y': 235, 'width': 356, 'height': 445}
# 11
# Class Label:  2
# Yolo Annotation:  [2, 0.1845703125, 0.595703125, 0.34765625, 0.5794270833333334]
# Region:  {'name': 'rect', 'x': 363, 'y': 248, 'width': 648, 'height': 441}
# 363
# Class Label:  1
# Yolo Annotation:  [1, 0.6708984375, 0.6100260416666666, 0.6328125, 0.57421875]
# -----------------------------------
# Img Name:  car27.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 9, 'y': 22, 'width': 428, 'height': 263}
# 9
# Class Label:  2
# Yolo Annotation:  [2, 0.4955555555555556, 0.5116666666666667, 0.9511111111111111, 0.8766666666666667]
# -----------------------------------
# Img Name:  car26.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 35, 'y': 51, 'width': 213, 'height': 124}
# 35
# Class Label:  0
# Yolo Annotation:  [0, 0.5463320463320464, 0.5824742268041238, 0.8223938223938224, 0.6391752577319587]
# -----------------------------------
# Img Name:  car25.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 40, 'y': 126, 'width': 1230, 'height': 744}
# 40
# Class Label:  1
# Yolo Annotation:  [1, 0.5038461538461538, 0.5203761755485894, 0.9461538461538461, 0.7774294670846394]
# -----------------------------------
# Img Name:  car24.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 74, 'y': 1, 'width': 152, 'height': 248}
# 74
# Class Label:  0
# Yolo Annotation:  [0, 0.42857142857142855, 0.4752851711026616, 0.4342857142857143, 0.9429657794676806]
# -----------------------------------
# Img Name:  car23.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 13, 'y': 23, 'width': 449, 'height': 435}
# 13
# Class Label:  1
# Yolo Annotation:  [1, 0.37109375, 0.5010416666666667, 0.7015625, 0.90625]
# Region:  {'name': 'rect', 'x': 463, 'y': 9, 'width': 125, 'height': 341}
# 463
# Class Label:  2
# Yolo Annotation:  [2, 0.82109375, 0.37395833333333334, 0.1953125, 0.7104166666666667]
# -----------------------------------
# Img Name:  car22.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 1, 'y': 38, 'width': 197, 'height': 146}
# 1
# Class Label:  2
# Yolo Annotation:  [2, 0.3841698841698842, 0.5721649484536082, 0.7606177606177607, 0.7525773195876289]
# Region:  {'name': 'rect', 'x': 202, 'y': 31, 'width': 56, 'height': 146}
# 202
# Class Label:  0
# Yolo Annotation:  [0, 0.888030888030888, 0.5360824742268041, 0.21621621621621623, 0.7525773195876289]
# -----------------------------------
# Img Name:  car21.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 30, 'y': 18, 'width': 650, 'height': 506}
# 30
# Class Label:  0
# Yolo Annotation:  [0, 0.4930555555555556, 0.5046554934823091, 0.9027777777777778, 0.9422718808193669]
# -----------------------------------
# Img Name:  car20.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 13, 'y': 32, 'width': 546, 'height': 447}
# 13
# Class Label:  2
# Yolo Annotation:  [2, 0.38133333333333336, 0.45381882770870335, 0.728, 0.7939609236234458]
# Region:  {'name': 'rect', 'x': 576, 'y': 9, 'width': 170, 'height': 373}
# 576
# Class Label:  1
# Yolo Annotation:  [1, 0.8813333333333333, 0.347246891651865, 0.22666666666666666, 0.6625222024866785]
# -----------------------------------
# Img Name:  car2.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 17, 'y': 9, 'width': 221, 'height': 207}
# 17
# Class Label:  0
# Yolo Annotation:  [0, 0.425, 0.5, 0.7366666666666667, 0.92]
# -----------------------------------
# Img Name:  car19.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 210, 'y': 11, 'width': 1763, 'height': 801}
# 210
# Class Label:  1
# Yolo Annotation:  [1, 0.54575, 0.36577777777777776, 0.8815, 0.712]
# -----------------------------------
# Img Name:  car18.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 42, 'y': 24, 'width': 352, 'height': 263}
# 42
# Class Label:  0
# Yolo Annotation:  [0, 0.545, 0.5183333333333333, 0.88, 0.8766666666666667]
# -----------------------------------
# Img Name:  car17.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 140, 'y': 35, 'width': 558, 'height': 464}
# 140
# Class Label:  1
# Yolo Annotation:  [1, 0.5943262411347517, 0.5056818181818182, 0.7914893617021277, 0.8787878787878788]
# -----------------------------------
# Img Name:  car16.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 7, 'y': 5, 'width': 444, 'height': 532}
# 7
# Class Label:  1
# Yolo Annotation:  [1, 0.28625, 0.45166666666666666, 0.555, 0.8866666666666667]
# Region:  {'name': 'rect', 'x': 491, 'y': 23, 'width': 295, 'height': 556}
# 491
# Class Label:  2
# Yolo Annotation:  [2, 0.798125, 0.5016666666666667, 0.36875, 0.9266666666666666]
# -----------------------------------
# Img Name:  car15.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 377, 'y': 2, 'width': 328, 'height': 214}
# 377
# Class Label:  0
# Yolo Annotation:  [0, 0.7566433566433567, 0.47391304347826085, 0.45874125874125876, 0.9304347826086956]
# -----------------------------------
# Img Name:  car141.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 140, 'y': 5, 'width': 216, 'height': 296}
# 140
# Class Label:  0
# Yolo Annotation:  [0, 0.5166666666666667, 0.425, 0.45, 0.8222222222222222]
# -----------------------------------
# Img Name:  car140.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 925, 'y': 27, 'width': 1157, 'height': 958}
# 925
# Class Label:  2
# Yolo Annotation:  [2, 0.7095327984898537, 0.3575971731448763, 0.5460122699386503, 0.6770318021201414]
# -----------------------------------
# Img Name:  car14.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 110, 'y': 41, 'width': 1158, 'height': 635}
# 110
# Class Label:  2
# Yolo Annotation:  [2, 0.53828125, 0.4979166666666667, 0.9046875, 0.8819444444444444]
# -----------------------------------
# Img Name:  car139.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 15, 'y': 17, 'width': 910, 'height': 817}
# 15
# Class Label:  0
# Yolo Annotation:  [0, 0.458984375, 0.41552734375, 0.888671875, 0.7978515625]
# -----------------------------------
# Img Name:  car138.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 79, 'y': 231, 'width': 662, 'height': 779}
# 79
# Class Label:  1
# Yolo Annotation:  [1, 0.400390625, 0.60595703125, 0.646484375, 0.7607421875]
# Region:  {'name': 'rect', 'x': 659, 'y': 46, 'width': 208, 'height': 218}
# 659
# Class Label:  2
# Yolo Annotation:  [2, 0.7451171875, 0.1513671875, 0.203125, 0.212890625]
# -----------------------------------
# Img Name:  car137.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 18, 'y': 235, 'width': 989, 'height': 578}
# 18
# Class Label:  1
# Yolo Annotation:  [1, 0.50048828125, 0.51171875, 0.9658203125, 0.564453125]
# -----------------------------------
# Img Name:  car136.jpeg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 128, 'y': 308, 'width': 835, 'height': 692}
# 128
# Class Label:  2
# Yolo Annotation:  [2, 0.53271484375, 0.638671875, 0.8154296875, 0.67578125]
# Region:  {'name': 'rect', 'x': 103, 'y': 7, 'width': 116, 'height': 259}
# 103
# Class Label:  2
# Yolo Annotation:  [2, 0.1572265625, 0.13330078125, 0.11328125, 0.2529296875]
# Region:  {'name': 'rect', 'x': 30, 'y': 5, 'width': 69, 'height': 130}
# 30
# Class Label:  2
# Yolo Annotation:  [2, 0.06298828125, 0.068359375, 0.0673828125, 0.126953125]
# -----------------------------------
# Img Name:  car135.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 2, 'y': 21, 'width': 527, 'height': 904}
# 2
# Class Label:  0
# Yolo Annotation:  [0, 0.25927734375, 0.4619140625, 0.5146484375, 0.8828125]
# Region:  {'name': 'rect', 'x': 519, 'y': 30, 'width': 497, 'height': 517}
# 519
# Class Label:  1
# Yolo Annotation:  [1, 0.74951171875, 0.28173828125, 0.4853515625, 0.5048828125]
# -----------------------------------
# Img Name:  car134.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 8, 'y': 11, 'width': 829, 'height': 926}
# 8
# Class Label:  0
# Yolo Annotation:  [0, 0.41259765625, 0.462890625, 0.8095703125, 0.904296875]
# -----------------------------------
# Img Name:  car133.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 431, 'y': 383, 'width': 565, 'height': 507}
# 431
# Class Label:  0
# Yolo Annotation:  [0, 0.69677734375, 0.62158203125, 0.5517578125, 0.4951171875]
# Region:  {'name': 'rect', 'x': 127, 'y': 225, 'width': 322, 'height': 554}
# 127
# Class Label:  1
# Yolo Annotation:  [1, 0.28125, 0.490234375, 0.314453125, 0.541015625]
# Region:  {'name': 'rect', 'x': 5, 'y': 109, 'width': 81, 'height': 153}
# 5
# Class Label:  0
# Yolo Annotation:  [0, 0.04443359375, 0.18115234375, 0.0791015625, 0.1494140625]
# -----------------------------------
# Img Name:  car132.jpeg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 93, 'y': 225, 'width': 896, 'height': 772}
# 93
# Class Label:  1
# Yolo Annotation:  [1, 0.5283203125, 0.5966796875, 0.875, 0.75390625]
# -----------------------------------
# Img Name:  car131.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 15, 'y': 122, 'width': 1006, 'height': 628}
# 15
# Class Label:  1
# Yolo Annotation:  [1, 0.505859375, 0.42578125, 0.982421875, 0.61328125]
# -----------------------------------
# Img Name:  car130.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 6, 'y': 91, 'width': 1014, 'height': 875}
# 6
# Class Label:  1
# Yolo Annotation:  [1, 0.5009765625, 0.51611328125, 0.990234375, 0.8544921875]
# -----------------------------------
# Img Name:  car13.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 64, 'y': 3, 'width': 223, 'height': 151}
# 64
# Class Label:  2
# Yolo Annotation:  [2, 0.585, 0.46726190476190477, 0.7433333333333333, 0.8988095238095238]
# -----------------------------------
# Img Name:  car129.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 244, 'y': 48, 'width': 761, 'height': 942}
# 244
# Class Label:  1
# Yolo Annotation:  [1, 0.60986328125, 0.5068359375, 0.7431640625, 0.919921875]
# -----------------------------------
# Img Name:  car128.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 71, 'y': 414, 'width': 573, 'height': 481}
# 71
# Class Label:  2
# Yolo Annotation:  [2, 0.34912109375, 0.63916015625, 0.5595703125, 0.4697265625]
# Region:  {'name': 'rect', 'x': 640, 'y': 425, 'width': 320, 'height': 343}
# 640
# Class Label:  1
# Yolo Annotation:  [1, 0.78125, 0.58251953125, 0.3125, 0.3349609375]
# Region:  {'name': 'rect', 'x': 8, 'y': 360, 'width': 182, 'height': 327}
# 8
# Class Label:  1
# Yolo Annotation:  [1, 0.0966796875, 0.51123046875, 0.177734375, 0.3193359375]
# -----------------------------------
# Img Name:  car127.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 32, 'y': 52, 'width': 429, 'height': 914}
# 32
# Class Label:  2
# Yolo Annotation:  [2, 0.24072265625, 0.4970703125, 0.4189453125, 0.892578125]
# Region:  {'name': 'rect', 'x': 479, 'y': 107, 'width': 537, 'height': 770}
# 479
# Class Label:  1
# Yolo Annotation:  [1, 0.72998046875, 0.48046875, 0.5244140625, 0.751953125]
# -----------------------------------
# Img Name:  car126.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 172, 'y': 247, 'width': 742, 'height': 582}
# 172
# Class Label:  0
# Yolo Annotation:  [0, 0.5302734375, 0.525390625, 0.724609375, 0.568359375]
# Region:  {'name': 'rect', 'x': 82, 'y': 116, 'width': 109, 'height': 399}
# 82
# Class Label:  1
# Yolo Annotation:  [1, 0.13330078125, 0.30810546875, 0.1064453125, 0.3896484375]
# Region:  {'name': 'rect', 'x': 881, 'y': 24, 'width': 139, 'height': 161}
# 881
# Class Label:  1
# Yolo Annotation:  [1, 0.92822265625, 0.10205078125, 0.1357421875, 0.1572265625]
# -----------------------------------
# Img Name:  car125.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 139, 'y': 282, 'width': 845, 'height': 658}
# 139
# Class Label:  0
# Yolo Annotation:  [0, 0.54833984375, 0.5966796875, 0.8251953125, 0.642578125]
# -----------------------------------
# Img Name:  car124.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 86, 'y': 267, 'width': 761, 'height': 728}
# 86
# Class Label:  0
# Yolo Annotation:  [0, 0.45556640625, 0.6162109375, 0.7431640625, 0.7109375]
# Region:  {'name': 'rect', 'x': 189, 'y': 110, 'width': 264, 'height': 133}
# 189
# Class Label:  1
# Yolo Annotation:  [1, 0.3134765625, 0.17236328125, 0.2578125, 0.1298828125]
# -----------------------------------
# Img Name:  car123.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 8, 'y': 63, 'width': 887, 'height': 932}
# 8
# Class Label:  0
# Yolo Annotation:  [0, 0.44091796875, 0.5166015625, 0.8662109375, 0.91015625]
# -----------------------------------
# Img Name:  car122.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 13, 'y': 13, 'width': 664, 'height': 879}
# 13
# Class Label:  2
# Yolo Annotation:  [2, 0.3369140625, 0.44189453125, 0.6484375, 0.8583984375]
# -----------------------------------
# Img Name:  car121.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 35, 'y': 407, 'width': 517, 'height': 446}
# 35
# Class Label:  2
# Yolo Annotation:  [2, 0.28662109375, 0.615234375, 0.5048828125, 0.435546875]
# Region:  {'name': 'rect', 'x': 566, 'y': 460, 'width': 412, 'height': 334}
# 566
# Class Label:  1
# Yolo Annotation:  [1, 0.75390625, 0.6123046875, 0.40234375, 0.326171875]
# Region:  {'name': 'rect', 'x': 940, 'y': 245, 'width': 81, 'height': 264}
# 940
# Class Label:  2
# Yolo Annotation:  [2, 0.95751953125, 0.3681640625, 0.0791015625, 0.2578125]
# -----------------------------------
# Img Name:  car120.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 30, 'y': 51, 'width': 711, 'height': 785}
# 30
# Class Label:  2
# Yolo Annotation:  [2, 0.37646484375, 0.43310546875, 0.6943359375, 0.7666015625]
# Region:  {'name': 'rect', 'x': 768, 'y': 38, 'width': 253, 'height': 622}
# 768
# Class Label:  1
# Yolo Annotation:  [1, 0.87353515625, 0.3408203125, 0.2470703125, 0.607421875]
# -----------------------------------
# Img Name:  car12.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 115, 'y': 17, 'width': 803, 'height': 392}
# 115
# Class Label:  2
# Yolo Annotation:  [2, 0.549468085106383, 0.49078341013824883, 0.8542553191489362, 0.9032258064516129]
# -----------------------------------
# Img Name:  car119.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 5, 'y': 381, 'width': 345, 'height': 490}
# 5
# Class Label:  0
# Yolo Annotation:  [0, 0.17333984375, 0.611328125, 0.3369140625, 0.478515625]
# Region:  {'name': 'rect', 'x': 458, 'y': 414, 'width': 556, 'height': 391}
# 458
# Class Label:  1
# Yolo Annotation:  [1, 0.71875, 0.59521484375, 0.54296875, 0.3818359375]
# -----------------------------------
# Img Name:  car118.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 21, 'y': 103, 'width': 464, 'height': 760}
# 21
# Class Label:  1
# Yolo Annotation:  [1, 0.2470703125, 0.4716796875, 0.453125, 0.7421875]
# Region:  {'name': 'rect', 'x': 531, 'y': 69, 'width': 488, 'height': 949}
# 531
# Class Label:  0
# Yolo Annotation:  [0, 0.7568359375, 0.53076171875, 0.4765625, 0.9267578125]
# -----------------------------------
# Img Name:  car117.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 44, 'y': 211, 'width': 743, 'height': 687}
# 44
# Class Label:  0
# Yolo Annotation:  [0, 0.40576171875, 0.54150390625, 0.7255859375, 0.6708984375]
# Region:  {'name': 'rect', 'x': 794, 'y': 231, 'width': 228, 'height': 397}
# 794
# Class Label:  1
# Yolo Annotation:  [1, 0.88671875, 0.41943359375, 0.22265625, 0.3876953125]
# Region:  {'name': 'rect', 'x': 0, 'y': 0, 'width': 368, 'height': 199}
# 0
# Class Label:  1
# Yolo Annotation:  [1, 0.1796875, 0.09716796875, 0.359375, 0.1943359375]
# -----------------------------------
# Img Name:  car116.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 27, 'y': 410, 'width': 862, 'height': 579}
# 27
# Class Label:  1
# Yolo Annotation:  [1, 0.447265625, 0.68310546875, 0.841796875, 0.5654296875]
# Region:  {'name': 'rect', 'x': 503, 'y': 52, 'width': 505, 'height': 717}
# 503
# Class Label:  0
# Yolo Annotation:  [0, 0.73779296875, 0.40087890625, 0.4931640625, 0.7001953125]
# -----------------------------------
# Img Name:  car115.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 14, 'y': 202, 'width': 657, 'height': 733}
# 14
# Class Label:  1
# Yolo Annotation:  [1, 0.33447265625, 0.55517578125, 0.6416015625, 0.7158203125]
# Region:  {'name': 'rect', 'x': 351, 'y': 32, 'width': 528, 'height': 720}
# 351
# Class Label:  2
# Yolo Annotation:  [2, 0.6005859375, 0.3828125, 0.515625, 0.703125]
# -----------------------------------
# Img Name:  car114.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 75, 'y': 6, 'width': 906, 'height': 961}
# 75
# Class Label:  0
# Yolo Annotation:  [0, 0.515625, 0.47509765625, 0.884765625, 0.9384765625]
# -----------------------------------
# Img Name:  car113.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 2, 'y': 332, 'width': 857, 'height': 611}
# 2
# Class Label:  1
# Yolo Annotation:  [1, 0.42041015625, 0.62255859375, 0.8369140625, 0.5966796875]
# Region:  {'name': 'rect', 'x': 628, 'y': 397, 'width': 389, 'height': 570}
# 628
# Class Label:  0
# Yolo Annotation:  [0, 0.80322265625, 0.666015625, 0.3798828125, 0.556640625]
# Region:  {'name': 'rect', 'x': 4, 'y': 144, 'width': 59, 'height': 80}
# 4
# Class Label:  0
# Yolo Annotation:  [0, 0.03271484375, 0.1796875, 0.0576171875, 0.078125]
# Region:  {'name': 'rect', 'x': 70, 'y': 144, 'width': 138, 'height': 71}
# 70
# Class Label:  1
# Yolo Annotation:  [1, 0.1357421875, 0.17529296875, 0.134765625, 0.0693359375]
# -----------------------------------
# Img Name:  car112.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 8, 'y': 6, 'width': 811, 'height': 1003}
# 8
# Class Label:  1
# Yolo Annotation:  [1, 0.40380859375, 0.49560546875, 0.7919921875, 0.9794921875]
# -----------------------------------
# Img Name:  car111.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 353, 'y': 19, 'width': 650, 'height': 866}
# 353
# Class Label:  2
# Yolo Annotation:  [2, 0.662109375, 0.44140625, 0.634765625, 0.845703125]
# Region:  {'name': 'rect', 'x': 0, 'y': 8, 'width': 336, 'height': 876}
# 0
# Class Label:  1
# Yolo Annotation:  [1, 0.1640625, 0.435546875, 0.328125, 0.85546875]
# -----------------------------------
# Img Name:  car110.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 172, 'y': 321, 'width': 669, 'height': 663}
# 172
# Class Label:  2
# Yolo Annotation:  [2, 0.49462890625, 0.63720703125, 0.6533203125, 0.6474609375]
# Region:  {'name': 'rect', 'x': 767, 'y': 181, 'width': 145, 'height': 481}
# 767
# Class Label:  1
# Yolo Annotation:  [1, 0.81982421875, 0.41162109375, 0.1416015625, 0.4697265625]
# -----------------------------------
# Img Name:  car11.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 7, 'y': 2, 'width': 646, 'height': 428}
# 7
# Class Label:  2
# Yolo Annotation:  [2, 0.4532967032967033, 0.44536082474226807, 0.8873626373626373, 0.8824742268041237]
# -----------------------------------
# Img Name:  car109.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 44, 'y': 390, 'width': 968, 'height': 614}
# 44
# Class Label:  1
# Yolo Annotation:  [1, 0.515625, 0.6806640625, 0.9453125, 0.599609375]
# -----------------------------------
# Img Name:  car108.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 141, 'y': 310, 'width': 826, 'height': 704}
# 141
# Class Label:  2
# Yolo Annotation:  [2, 0.541015625, 0.646484375, 0.806640625, 0.6875]
# Region:  {'name': 'rect', 'x': 97, 'y': 0, 'width': 114, 'height': 267}
# 97
# Class Label:  2
# Yolo Annotation:  [2, 0.150390625, 0.13037109375, 0.111328125, 0.2607421875]
# Region:  {'name': 'rect', 'x': 28, 'y': 8, 'width': 87, 'height': 145}
# 28
# Class Label:  2
# Yolo Annotation:  [2, 0.06982421875, 0.07861328125, 0.0849609375, 0.1416015625]
# -----------------------------------
# Img Name:  car107.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 823, 'y': 96, 'width': 52, 'height': 48}
# 823
# Class Label:  2
# Yolo Annotation:  [2, 0.8291015625, 0.1171875, 0.05078125, 0.046875]
# Region:  {'name': 'rect', 'x': 883, 'y': 95, 'width': 62, 'height': 59}
# 883
# Class Label:  2
# Yolo Annotation:  [2, 0.892578125, 0.12158203125, 0.060546875, 0.0576171875]
# Region:  {'name': 'rect', 'x': 954, 'y': 98, 'width': 58, 'height': 55}
# 954
# Class Label:  2
# Yolo Annotation:  [2, 0.9599609375, 0.12255859375, 0.056640625, 0.0537109375]
# Region:  {'name': 'rect', 'x': 158, 'y': 40, 'width': 738, 'height': 917}
# 158
# Class Label:  0
# Yolo Annotation:  [0, 0.5146484375, 0.48681640625, 0.720703125, 0.8955078125]
# -----------------------------------
# Img Name:  car106.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 107, 'y': 17, 'width': 911, 'height': 870}
# 107
# Class Label:  2
# Yolo Annotation:  [2, 0.54931640625, 0.44140625, 0.8896484375, 0.849609375]
# Region:  {'name': 'rect', 'x': 52, 'y': 16, 'width': 155, 'height': 719}
# 52
# Class Label:  1
# Yolo Annotation:  [1, 0.12646484375, 0.36669921875, 0.1513671875, 0.7021484375]
# -----------------------------------
# Img Name:  car105.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 46, 'y': 326, 'width': 610, 'height': 548}
# 46
# Class Label:  0
# Yolo Annotation:  [0, 0.3427734375, 0.5859375, 0.595703125, 0.53515625]
# Region:  {'name': 'rect', 'x': 650, 'y': 279, 'width': 357, 'height': 493}
# 650
# Class Label:  1
# Yolo Annotation:  [1, 0.80908203125, 0.51318359375, 0.3486328125, 0.4814453125]
# -----------------------------------
# Img Name:  car104.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 233, 'y': 453, 'width': 617, 'height': 299}
# 233
# Class Label:  1
# Yolo Annotation:  [1, 0.52880859375, 0.58837890625, 0.6025390625, 0.2919921875]
# Region:  {'name': 'rect', 'x': 99, 'y': 496, 'width': 113, 'height': 252}
# 99
# Class Label:  0
# Yolo Annotation:  [0, 0.15185546875, 0.607421875, 0.1103515625, 0.24609375]
# -----------------------------------
# Img Name:  car103.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 28, 'y': 467, 'width': 591, 'height': 515}
# 28
# Class Label:  1
# Yolo Annotation:  [1, 0.31591796875, 0.70751953125, 0.5771484375, 0.5029296875]
# Region:  {'name': 'rect', 'x': 454, 'y': 494, 'width': 562, 'height': 514}
# 454
# Class Label:  0
# Yolo Annotation:  [0, 0.7177734375, 0.7333984375, 0.548828125, 0.501953125]
# Region:  {'name': 'rect', 'x': 0, 'y': 241, 'width': 127, 'height': 193}
# 0
# Class Label:  1
# Yolo Annotation:  [1, 0.06201171875, 0.32958984375, 0.1240234375, 0.1884765625]
# Region:  {'name': 'rect', 'x': 562, 'y': 262, 'width': 36, 'height': 34}
# 562
# Class Label:  0
# Yolo Annotation:  [0, 0.56640625, 0.2724609375, 0.03515625, 0.033203125]
# Region:  {'name': 'rect', 'x': 672, 'y': 263, 'width': 46, 'height': 28}
# 672
# Class Label:  0
# Yolo Annotation:  [0, 0.6787109375, 0.2705078125, 0.044921875, 0.02734375]
# Region:  {'name': 'rect', 'x': 605, 'y': 258, 'width': 59, 'height': 30}
# 605
# Class Label:  1
# Yolo Annotation:  [1, 0.61962890625, 0.2666015625, 0.0576171875, 0.029296875]
# Region:  {'name': 'rect', 'x': 795, 'y': 262, 'width': 39, 'height': 24}
# 795
# Class Label:  0
# Yolo Annotation:  [0, 0.79541015625, 0.267578125, 0.0380859375, 0.0234375]
# Region:  {'name': 'rect', 'x': 840, 'y': 253, 'width': 39, 'height': 29}
# 840
# Class Label:  1
# Yolo Annotation:  [1, 0.83935546875, 0.26123046875, 0.0380859375, 0.0283203125]
# Region:  {'name': 'rect', 'x': 962, 'y': 250, 'width': 42, 'height': 30}
# 962
# Class Label:  0
# Yolo Annotation:  [0, 0.9599609375, 0.2587890625, 0.041015625, 0.029296875]
# Region:  {'name': 'rect', 'x': 722, 'y': 258, 'width': 49, 'height': 29}
# 722
# Class Label:  1
# Yolo Annotation:  [1, 0.72900390625, 0.26611328125, 0.0478515625, 0.0283203125]
# -----------------------------------
# Img Name:  car102.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 64, 'y': 463, 'width': 726, 'height': 293}
# 64
# Class Label:  1
# Yolo Annotation:  [1, 0.4169921875, 0.59521484375, 0.708984375, 0.2861328125]
# Region:  {'name': 'rect', 'x': 5, 'y': 294, 'width': 153, 'height': 84}
# 5
# Class Label:  1
# Yolo Annotation:  [1, 0.07958984375, 0.328125, 0.1494140625, 0.08203125]
# Region:  {'name': 'rect', 'x': 593, 'y': 274, 'width': 200, 'height': 65}
# 593
# Class Label:  1
# Yolo Annotation:  [1, 0.6767578125, 0.29931640625, 0.1953125, 0.0634765625]
# Region:  {'name': 'rect', 'x': 744, 'y': 439, 'width': 188, 'height': 258}
# 744
# Class Label:  0
# Yolo Annotation:  [0, 0.818359375, 0.5546875, 0.18359375, 0.251953125]
# -----------------------------------
# Img Name:  car101.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 113, 'y': 279, 'width': 826, 'height': 611}
# 113
# Class Label:  0
# Yolo Annotation:  [0, 0.513671875, 0.57080078125, 0.806640625, 0.5966796875]
# -----------------------------------
# Img Name:  car100.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 170, 'y': 191, 'width': 583, 'height': 651}
# 170
# Class Label:  0
# Yolo Annotation:  [0, 0.45068359375, 0.50439453125, 0.5693359375, 0.6357421875]
# Region:  {'name': 'rect', 'x': 743, 'y': 150, 'width': 248, 'height': 527}
# 743
# Class Label:  1
# Yolo Annotation:  [1, 0.8466796875, 0.40380859375, 0.2421875, 0.5146484375]
# Region:  {'name': 'rect', 'x': 322, 'y': 2, 'width': 133, 'height': 79}
# 322
# Class Label:  0
# Yolo Annotation:  [0, 0.37939453125, 0.04052734375, 0.1298828125, 0.0771484375]
# Region:  {'name': 'rect', 'x': 963, 'y': 40, 'width': 56, 'height': 168}
# 963
# Class Label:  0
# Yolo Annotation:  [0, 0.9677734375, 0.12109375, 0.0546875, 0.1640625]
# Region:  {'name': 'rect', 'x': 6, 'y': 57, 'width': 97, 'height': 139}
# 6
# Class Label:  0
# Yolo Annotation:  [0, 0.05322265625, 0.12353515625, 0.0947265625, 0.1357421875]
# -----------------------------------
# Img Name:  car10.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 16, 'y': 7, 'width': 403, 'height': 563}
# 16
# Class Label:  0
# Yolo Annotation:  [0, 0.453125, 0.45078125, 0.8395833333333333, 0.8796875]
# -----------------------------------
# Img Name:  car1.jpg
# -----------------------------------
# Region:  {'name': 'rect', 'x': 21, 'y': 5, 'width': 562, 'height': 425}
# 21
# Class Label:  0
# Yolo Annotation:  [0, 0.43768115942028984, 0.4198841698841699, 0.8144927536231884, 0.8204633204633205]
# -----------------------------------
# 0

# %% [markdown]
# # Get YAML file for YOLOV5

# %%
# train: data/YoloDataset/train/images
# val: data/YoloDataset/test/images

# nc: 3
# names: ['Back', 'Front', 'Side']
data_file = [   "train: <TO BE FILLED LATER>",
                "val: <TO BE FILLED LATER>",
                "test: <OPTIONAL: TO BE FILLED LATER>",
                "",
                "nc: " + str(len(labels)), 
                "names: " + str([labels.inverse[i] for i in range(len(labels))])
            ]
print(data_file)
# Out:
# ['train: <TO BE FILLED LATER>', 'val: <TO BE FILLED LATER>', 'test: <OPTIONAL: TO BE FILLED LATER>', '', 'nc: 3', "names: ['Front', 'Side', 'Back']"]

# %%
# Saving to txt
with open(os.path.join(output_dir, 'data.yaml'), 'w') as f:
    f.writelines("\n".join(data_file))
